# %%
# !pip install -q -U google-generativeai

# %%
import google.generativeai as genai
import os
import pprint
GOOGLE_API_KEY=os.getenv('GOOGLE_API_KEY')
genai.configure(api_key=GOOGLE_API_KEY)

# Set up the model
generation_config = {
  "temperature": 0.9,
  "top_p": 1,
  "top_k": 1,
  "max_output_tokens": 2048,
}

safety_settings = [
  {
    "category": "HARM_CATEGORY_HARASSMENT",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  },
  {
    "category": "HARM_CATEGORY_HATE_SPEECH",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  },
  {
    "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  },
  {
    "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  }
]

model = genai.GenerativeModel(model_name="gemini-pro",
                              generation_config=generation_config,
                              safety_settings=safety_settings)

prompt_parts = [
  "What is google Gemini AI?",
]

response = model.generate_content(prompt_parts)
pprint.pprint(response.text)
# Out:
# ('Google Gemini AI, also known as Generative Model for Entity Matching with '
#  'Incomplete Knowledge (GEMINI), is a machine learning model developed by '
#  'Google to tackle entity matching tasks, particularly in the presence of '
#  "incomplete information. Here's an overview of Google Gemini AI:\n"
#  '\n'
#  '**Introduction**:\n'
#  'Entity matching, also known as record linkage or entity resolution, involves '
#  'identifying and linking different records that refer to the same real-world '
#  'entity from potentially diverse datasets or sources. This task is crucial in '
#  'various domains, such as data integration, knowledge graph construction, and '
#  'business intelligence.\n'
#  '\n'
#  '**Challenges and Incomplete Knowledge**:\n'
#  'Traditional entity matching algorithms often rely on exact or near-exact '
#  'string matching rules. However, in real-world scenarios, records may contain '
#  'incomplete or noisy information, making exact matching insufficient. For '
#  "example, an address might be missing a street number or a person's name "
#  'might be abbreviated.\n'
#  '\n'
#  '**Approach of Google Gemini AI**:\n'
#  'Google Gemini AI addresses these challenges by leveraging machine learning '
#  'techniques to train a model that can perform entity matching even with '
#  'incomplete knowledge. Gemini AI utilizes a generative adversarial network '
#  '(GAN) architecture, where two neural networks, a generator and a '
#  'discriminator, are trained in an adversarial manner.\n'
#  '\n'
#  '**Generator Network**:\n'
#  'The generator network aims to generate plausible entity pairs that represent '
#  'potential matches. It generates pairs by sampling from a joint distribution '
#  'of entities from two datasets, considering their features and structural '
#  'similarities.\n'
#  '\n'
#  '**Discriminator Network**:\n'
#  'The discriminator network, on the other hand, aims to distinguish between '
#  'the generated pairs and true entity pairs. It is trained to classify pairs '
#  'as either matching or non-matching.\n'
#  '\n'
#  '**Adversarial Training**:\n'
#  'The generator and discriminator networks are trained in an adversarial '
#  'fashion, where the generator tries to fool the discriminator by generating '
#  'more realistic entity pairs, while the discriminator attempts to accurately '
#  'identify true matches. This adversarial training process helps the generator '
#  'learn to capture the characteristics of true matches, even in the presence '
#  'of incomplete information.\n'
#  '\n'
#  '**Output of Google Gemini AI**:\n'
#  'After training, Google Gemini AI provides a similarity score and a matching '
#  'probability for each pair of entities. This allows users to rank entity '
#  'pairs by their likelihood of representing true matches and select the most '
#  'likely matches for their specific application.\n'
#  '\n'
#  '**Benefits and Applications**:\n'
#  'Google Gemini AI offers several benefits, including:\n'
#  '- Ability to handle incomplete or noisy data\n'
#  '- High accuracy in entity matching tasks\n'
#  '- Robustness to different types of datasets and domains\n'
#  '\n'
#  'Gemini AI has been successfully applied in various domains such as data '
#  'integration, knowledge graph construction, customer relationship management '
#  '(CRM), and fraud detection.\n'
#  '\n'
#  'In summary, Google Gemini AI is a state-of-the-art machine learning model '
#  'for entity matching, particularly in scenarios with incomplete knowledge. It '
#  'leverages a GAN architecture and adversarial training to learn from both '
#  'true matches and generated pairs, resulting in accurate and robust entity '
#  'matching capabilities.')
